# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\Arth Shukhla\OneDrive\Desktop\6. India Census 2011.csv")

# %%
df.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164  \
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs
# 0    439654   229064        190899           38165  ...        1700   5600  \
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
df[df["District_name"].isin(["Allahabad","New Delhi"])]
# Out:
#      District_code     State_name District_name  Population     Male   Female
# 93              94   NCT OF DELHI     New Delhi      142004    77942    64062  \
# 174            175  UTTAR PRADESH     Allahabad     5954391  3131807  2822584
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs
# 93     114179    59541         46940           12601  ...        4852   2933  \
# 174   3665727  2111907       1426110          685797  ...       13782   4377
#
#      Buddhists  Jains  Secondary_Education  Higher_Education
# 93         312    679                15942             17742  \
# 174       4391   2247               596615            502826
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 93                23934           76076            43913         21773
# 174              428871         3764404          1335224        818137
#
# [2 rows x 25 columns]

# %%
male=df.groupby("State_name")["Male"].sum().sort_values(ascending=False)

# %%
male
# Out:
# State_name
# UTTAR PRADESH                  104480510
# MAHARASHTRA                     58243056
# BIHAR                           54278157
# WEST BENGAL                     46809027
# ANDHRA PRADESH                  42442146
# MADHYA PRADESH                  37612306
# TAMIL NADU                      36137975
# RAJASTHAN                       35550997
# GUJARAT                         31491260
# KARNATAKA                       30966657
# ORISSA                          21212136
# JHARKHAND                       16930315
# KERALA                          16027412
# ASSAM                           15939443
# PUNJAB                          14639465
# HARYANA                         13494734
# CHHATTISGARH                    12832895
# NCT OF DELHI                     8987326
# JAMMU AND KASHMIR                6640662
# UTTARAKHAND                      5137773
# HIMACHAL PRADESH                 3481873
# TRIPURA                          1874376
# ...

# %%
df.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164  \
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs
# 0    439654   229064        190899           38165  ...        1700   5600  \
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education
# 0         66     39                74948             39709  \
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['District_code', 'State_name', 'District_name', 'Population', 'Male',
#        'Female', 'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50'],
#       dtype='object')

# %%
per=df["Muslims"]/df["Population"]*100

# %%
per
# Out:
# 0      94.592086
# 1      97.652920
# 2      14.276297
# 3      76.873198
# 4      90.446171
#          ...
# 635    30.744213
# 636    14.401514
# 637     3.626296
# 638     2.050248
# 639    12.140656
# Length: 640, dtype: float64

# %%
st=df.groupby("State_name")["Population"].sum()

# %%
st
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS       380581
# ANDHRA PRADESH                  84580777
# ARUNACHAL PRADESH                1383727
# ASSAM                           31205576
# BIHAR                          104099452
# CHANDIGARH                       1055450
# CHHATTISGARH                    25545198
# DADRA AND NAGAR HAVELI            343709
# DAMAN AND DIU                     243247
# GOA                              1458545
# GUJARAT                         60439692
# HARYANA                         25351462
# HIMACHAL PRADESH                 6864602
# JAMMU AND KASHMIR               12541302
# JHARKHAND                       32988134
# KARNATAKA                       61095297
# KERALA                          33406061
# LAKSHADWEEP                        64473
# MADHYA PRADESH                  72626809
# MAHARASHTRA                    112374333
# MANIPUR                          2855794
# MEGHALAYA                        2966889
# ...

# %%
ms=df.groupby("State_name")["Muslims"].sum()

# %% [markdown]
# ms

# %%
ms
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS       32413
# ANDHRA PRADESH                  8082412
# ARUNACHAL PRADESH                 27045
# ASSAM                          10679345
# BIHAR                          17557809
# CHANDIGARH                        51447
# CHHATTISGARH                     514998
# DADRA AND NAGAR HAVELI            12922
# DAMAN AND DIU                     19277
# GOA                              121564
# GUJARAT                         5846761
# HARYANA                         1781342
# HIMACHAL PRADESH                 149881
# JAMMU AND KASHMIR               8567485
# JHARKHAND                       4793994
# KARNATAKA                       7893065
# KERALA                          8873472
# LAKSHADWEEP                       62268
# MADHYA PRADESH                  4774695
# MAHARASHTRA                    12971152
# MANIPUR                          239836
# MEGHALAYA                        130399
# MIZORAM                           14832
# ...

# %%
li=df.groupby("State_name")["Literate"].sum().sort_values(ascending=False)

# %%
li
# Out:
# State_name
# UTTAR PRADESH                  114397555
# MAHARASHTRA                     81554290
# WEST BENGAL                     61538281
# BIHAR                           52504553
# TAMIL NADU                      51837507
# ANDHRA PRADESH                  50556760
# MADHYA PRADESH                  42851169
# GUJARAT                         41093358
# KARNATAKA                       40647322
# RAJASTHAN                       38275282
# KERALA                          28135824
# ORISSA                          26742595
# ASSAM                           19177977
# PUNJAB                          18707137
# JHARKHAND                       18328069
# HARYANA                         16598988
# CHHATTISGARH                    15379922
# NCT OF DELHI                    12737767
# JAMMU AND KASHMIR                7067233
# UTTARAKHAND                      6880953
# HIMACHAL PRADESH                 5039736
# TRIPURA                          2804783
# ...

# %%
df.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164  \
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs
# 0    439654   229064        190899           38165  ...        1700   5600  \
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
aa=df.groupby("State_name").Muslims.agg("max")

# %%
aa
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS      28912
# ANDHRA PRADESH                 1713405
# ARUNACHAL PRADESH                 6148
# ASSAM                          1563203
# BIHAR                          1365645
# CHANDIGARH                       51447
# CHHATTISGARH                    103038
# DADRA AND NAGAR HAVELI           12922
# DAMAN AND DIU                    16087
# GOA                              63623
# GUJARAT                         883238
# HARYANA                         862647
# HIMACHAL PRADESH                 33215
# JAMMU AND KASHMIR              1177342
# JHARKHAND                       508586
# KARNATAKA                      1248294
# KERALA                         2888849
# LAKSHADWEEP                      62268
# MADHYA PRADESH                  525434
# MAHARASHTRA                    1795788
# MANIPUR                         107323
# MEGHALAYA                       106788
# MIZORAM                           5264
# NAGALAND                         31212
# ...

# %%
dff=ms.to_frame()

# %%
dff
# Out:
#                               Muslims
# State_name
# ANDAMAN AND NICOBAR ISLANDS     32413
# ANDHRA PRADESH                8082412
# ARUNACHAL PRADESH               27045
# ASSAM                        10679345
# BIHAR                        17557809
# CHANDIGARH                      51447
# CHHATTISGARH                   514998
# DADRA AND NAGAR HAVELI          12922
# DAMAN AND DIU                   19277
# GOA                            121564
# GUJARAT                       5846761
# HARYANA                       1781342
# HIMACHAL PRADESH               149881
# JAMMU AND KASHMIR             8567485
# JHARKHAND                     4793994
# KARNATAKA                     7893065
# KERALA                        8873472
# LAKSHADWEEP                     62268
# MADHYA PRADESH                4774695
# MAHARASHTRA                  12971152
# MANIPUR                        239836
# MEGHALAYA                      130399
# MIZORAM                         14832
# ...

# %%
stt=st.to_frame()

# %%
stt
# Out:
#                              Population
# State_name
# ANDAMAN AND NICOBAR ISLANDS      380581
# ANDHRA PRADESH                 84580777
# ARUNACHAL PRADESH               1383727
# ASSAM                          31205576
# BIHAR                         104099452
# CHANDIGARH                      1055450
# CHHATTISGARH                   25545198
# DADRA AND NAGAR HAVELI           343709
# DAMAN AND DIU                    243247
# GOA                             1458545
# GUJARAT                        60439692
# HARYANA                        25351462
# HIMACHAL PRADESH                6864602
# JAMMU AND KASHMIR              12541302
# JHARKHAND                      32988134
# KARNATAKA                      61095297
# KERALA                         33406061
# LAKSHADWEEP                       64473
# MADHYA PRADESH                 72626809
# MAHARASHTRA                   112374333
# MANIPUR                         2855794
# MEGHALAYA                       2966889
# ...

# %%
percentage=[dff["Muslims"]/stt["Population"]*100]

# %%
# Muslims population percentage statewise
percentage
# Out:
# [State_name
#  ANDAMAN AND NICOBAR ISLANDS     8.516715
#  ANDHRA PRADESH                  9.555850
#  ARUNACHAL PRADESH               1.954504
#  ASSAM                          34.222554
#  BIHAR                          16.866380
#  CHANDIGARH                      4.874414
#  CHHATTISGARH                    2.016027
#  DADRA AND NAGAR HAVELI          3.759576
#  DAMAN AND DIU                   7.924866
#  GOA                             8.334607
#  GUJARAT                         9.673711
#  HARYANA                         7.026585
#  HIMACHAL PRADESH                2.183390
#  JAMMU AND KASHMIR              68.314159
#  JHARKHAND                      14.532480
#  KARNATAKA                      12.919268
#  KERALA                         26.562461
#  LAKSHADWEEP                    96.579964
#  MADHYA PRADESH                  6.574287
#  MAHARASHTRA                    11.542807
#  MANIPUR                         8.398225
#  MEGHALAYA                       4.395143
# ...

# %%
df.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164  \
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs
# 0    439654   229064        190899           38165  ...        1700   5600  \
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education
# 0         66     39                74948             39709  \
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %%
#number of literate statewise
literate=li.to_frame()

# %%
literate
# Out:
#                               Literate
# State_name
# UTTAR PRADESH                114397555
# MAHARASHTRA                   81554290
# WEST BENGAL                   61538281
# BIHAR                         52504553
# TAMIL NADU                    51837507
# ANDHRA PRADESH                50556760
# MADHYA PRADESH                42851169
# GUJARAT                       41093358
# KARNATAKA                     40647322
# RAJASTHAN                     38275282
# KERALA                        28135824
# ORISSA                        26742595
# ASSAM                         19177977
# PUNJAB                        18707137
# JHARKHAND                     18328069
# HARYANA                       16598988
# CHHATTISGARH                  15379922
# NCT OF DELHI                  12737767
# JAMMU AND KASHMIR              7067233
# UTTARAKHAND                    6880953
# HIMACHAL PRADESH               5039736
# TRIPURA                        2804783
# MANIPUR                        1908476
# ...

# %%
literacy_percentage=[literate["Literate"]/stt["Population"]*100]
literacy_percentage
# Out:
# [State_name
#  ANDAMAN AND NICOBAR ISLANDS    77.324144
#  ANDHRA PRADESH                 59.773345
#  ARUNACHAL PRADESH              55.358102
#  ASSAM                          61.456892
#  BIHAR                          50.436916
#  CHANDIGARH                     76.312284
#  CHHATTISGARH                   60.206705
#  DADRA AND NAGAR HAVELI         64.947383
#  DAMAN AND DIU                  77.454604
#  GOA                            79.907511
#  GUJARAT                        67.990681
#  HARYANA                        65.475466
#  HIMACHAL PRADESH               73.416288
#  JAMMU AND KASHMIR              56.351669
#  JHARKHAND                      55.559581
#  KARNATAKA                      66.531016
#  KERALA                         84.223710
#  LAKSHADWEEP                    81.511641
#  MADHYA PRADESH                 59.001861
#  MAHARASHTRA                    72.573770
#  MANIPUR                        66.828210
#  MEGHALAYA                      60.164199
# ...
